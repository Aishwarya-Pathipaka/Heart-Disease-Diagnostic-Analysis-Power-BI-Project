# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("C:\Projects\Heart Disease Diagnostic Analysis\heart_disease_dataset.csv")

# %%
data
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0     63    1   1       145   233    1        2      150      0      2.3
# 1     67    1   4       160   286    0        2      108      1      1.5
# 2     67    1   4       120   229    0        2      129      1      2.6
# 3     37    1   3       130   250    0        0      187      0      3.5
# 4     41    0   2       130   204    0        2      172      0      1.4
# ..   ...  ...  ..       ...   ...  ...      ...      ...    ...      ...
# 298   45    1   1       110   264    0        0      132      0      1.2
# 299   68    1   4       144   193    1        0      141      0      3.4
# 300   57    1   4       130   131    0        0      115      1      1.2
# 301   57    0   2       130   236    0        2      174      0      0.0
# 302   38    1   3       138   175    0        0      173      0      0.0
#
#      slope      ca  thal  num
# 0        3       0     6    0
# 1        2       3     3    1
# 2        2       2     7    1
# 3        3       0     3    0
# 4        1       0     3    0
# ..     ...     ...   ...  ...
# 298      2       0     7    1
# 299      2       2     7    1
# 300      2       1     7    1
# 301      2       1     3    1
# 302      1 -100000     3    0
#
# [303 rows x 14 columns]

# %%
data.head(20)   #Top 20
# Out:
#     age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 0    63    1   1       145   233    1        2      150      0      2.3
# 1    67    1   4       160   286    0        2      108      1      1.5
# 2    67    1   4       120   229    0        2      129      1      2.6
# 3    37    1   3       130   250    0        0      187      0      3.5
# 4    41    0   2       130   204    0        2      172      0      1.4
# 5    56    1   2       120   236    0        0      178      0      0.8
# 6    62    0   4       140   268    0        2      160      0      3.6
# 7    57    0   4       120   354    0        0      163      1      0.6
# 8    63    1   4       130   254    0        2      147      0      1.4
# 9    53    1   4       140   203    1        2      155      1      3.1
# 10   57    1   4       140   192    0        0      148      0      0.4
# 11   56    0   2       140   294    0        2      153      0      1.3
# 12   56    1   3       130   256    1        2      142      1      0.6
# 13   44    1   2       120   263    0        0      173      0      0.0
# 14   52    1   3       172   199    1        0      162      0      0.5
# 15   57    1   3       150   168    0        0      174      0      1.6
# 16   48    1   2       110   229    0        0      168      0      1.0
# 17   54    1   4       140   239    0        0      160      0      1.2
# 18   48    0   3       130   275    0        0      139      0      0.2
# 19   49    1   2       130   266    0        0      171      0      0.6
#
#     slope  ca  thal  num
# 0       3   0     6    0
# 1       2   3     3    1
# 2       2   2     7    1
# 3       3   0     3    0
# 4       1   0     3    0
# 5       1   0     3    0
# 6       3   2     3    1
# 7       1   0     3    0
# 8       2   1     7    1
# 9       3   0     7    1
# 10      2   0     6    0
# 11      2   0     3    0
# 12      2   1     6    1
# 13      1   0     7    0
# 14      1   0     7    0
# 15      1   0     3    0
# 16      3   0     7    1
# 17      1   0     3    0
# 18      1   0     3    0
# 19      1   0     3    0

# %%
data.info()         #Checking the numerical and categorical features
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  num       303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.describe()          ## Checking the statistical values
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.438944    0.679868    3.158416  131.689769  246.693069    0.148515
# std      9.038662    0.467299    0.960126   17.599748   51.776918    0.356198
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  211.000000    0.000000
# 50%     56.000000    1.000000    3.000000  130.000000  241.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  275.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.990099  149.607261    0.326733    1.039604    1.600660
# std      0.994971   22.875003    0.469794    1.161075    0.616226
# min      0.000000   71.000000    0.000000    0.000000    1.000000
# 25%      0.000000  133.500000    0.000000    0.000000    1.000000
# 50%      1.000000  153.000000    0.000000    0.800000    2.000000
# 75%      2.000000  166.000000    1.000000    1.600000    2.000000
# max      2.000000  202.000000    1.000000    6.200000    3.000000
#
#                   ca           thal         num
# count     303.000000     303.000000  303.000000
# mean    -1319.468647    -655.363036    0.458746
# std     11432.566205    8111.366638    0.499120
# min   -100000.000000 -100000.000000    0.000000
# 25%         0.000000       3.000000    0.000000
# 50%         0.000000       3.000000    0.000000
# 75%         1.000000       7.000000    1.000000
# max         3.000000       7.000000    1.000000

# %%
data.columns        #Full details about columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'num'],
#       dtype='object')

# %% [markdown]
# There are fourteen features in Dataset:
#
# 1) - age:The person's age in years
#
# 2) - sex: The person's sex (1 = male, 0 = female)
#
# 3) - cp: The chest pain experienced (Value 1: typical angina, Value 2: atypical angina, Value 3: non-anginal pain, Value 4:      asymptomatic)
#
# 4) - trestbps: The person's resting blood pressure (mm Hg on admission to the hospital)
#
# 5) - chol: The person's cholesterol measurement in mg/dl
#
# 6) - fbs: The person's fasting blood sugar (> 120 mg/dl, 1 = true; 0 = false)
#
# 7) - restecg: Resting electrocardiographic measurement (0 = normal, 1 = having ST-T wave abnormality, 2 = showing probable      or definite left ventricular hypertrophy by Estes' criteria)
#
# 8) - thalach: The person's maximum heart rate achieved
#
# 9) - exang: Exercise induced angina (1 = yes; 0 = no)
#
# 10) - oldpeak: ST depression induced by exercise relative to rest
#
# 11) - slope: the slope of the peak exercise ST segment (Value 1: upsloping, Value 2: flat, Value 3: downsloping)
#
# 12) - ca: The number of major vessels (0-3)
#
# 13) - thal: A blood disorder called thalassemia (3 = normal; 6 = fixed defect; 7 = reversable defect)
#
# 14) - num: Heart disease (0 = no, 1 = yes)

# %%
## Checking the Missing Values as we have to fill them

data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# num         0
# dtype: int64

# %% [markdown]
# ### Changing the numerical values to cartegorical values for a clear understanding of reports

# %%
def cp(row):
    if row == 1:
        return ' typical angina'
    elif row == 2:
        return 'atypical angina'
    elif row == 3:
        return 'non-anginal pain'
    elif row == 4 :
        return 'asymptomatic'

# %%
data['cp'] = data['cp'].apply(cp)

# %%
data
# Out:
#      age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1    typical angina       145   233    1        2      150      0
# 1     67    1      asymptomatic       160   286    0        2      108      1
# 2     67    1      asymptomatic       120   229    0        2      129      1
# 3     37    1  non-anginal pain       130   250    0        0      187      0
# 4     41    0   atypical angina       130   204    0        2      172      0
# ..   ...  ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    1    typical angina       110   264    0        0      132      0
# 299   68    1      asymptomatic       144   193    1        0      141      0
# 300   57    1      asymptomatic       130   131    0        0      115      1
# 301   57    0   atypical angina       130   236    0        2      174      0
# 302   38    1  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak  slope      ca  thal  num
# 0        2.3      3       0     6    0
# 1        1.5      2       3     3    1
# 2        2.6      2       2     7    1
# 3        3.5      3       0     3    0
# 4        1.4      1       0     3    0
# ..       ...    ...     ...   ...  ...
# 298      1.2      2       0     7    1
# 299      3.4      2       2     7    1
# 300      1.2      2       1     7    1
# 301      0.0      2       1     3    1
# 302      0.0      1 -100000     3    0
#
# [303 rows x 14 columns]

# %%
def slope(row):
    if row == 1:
        return 'upsloping'
    elif row == 2:
        return 'flat'
    elif row == 3:
        return 'downsloping'

# %%
data['slope'] = data['slope'].apply(slope)

# %%
data
# Out:
#      age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1    typical angina       145   233    1        2      150      0
# 1     67    1      asymptomatic       160   286    0        2      108      1
# 2     67    1      asymptomatic       120   229    0        2      129      1
# 3     37    1  non-anginal pain       130   250    0        0      187      0
# 4     41    0   atypical angina       130   204    0        2      172      0
# ..   ...  ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    1    typical angina       110   264    0        0      132      0
# 299   68    1      asymptomatic       144   193    1        0      141      0
# 300   57    1      asymptomatic       130   131    0        0      115      1
# 301   57    0   atypical angina       130   236    0        2      174      0
# 302   38    1  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak        slope      ca  thal  num
# 0        2.3  downsloping       0     6    0
# 1        1.5         flat       3     3    1
# 2        2.6         flat       2     7    1
# 3        3.5  downsloping       0     3    0
# 4        1.4    upsloping       0     3    0
# ..       ...          ...     ...   ...  ...
# 298      1.2         flat       0     7    1
# 299      3.4         flat       2     7    1
# 300      1.2         flat       1     7    1
# 301      0.0         flat       1     3    1
# 302      0.0    upsloping -100000     3    0
#
# [303 rows x 14 columns]

# %%
def thal(row):
    if row == 3:
        return 'normal'
    elif row == 6:
        return 'fixed defect'
    elif row == 7:
        return 'reversable defect'

# %%
data['thal'] = data['thal'].apply(thal)

# %%
data
# Out:
#      age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1    typical angina       145   233    1        2      150      0
# 1     67    1      asymptomatic       160   286    0        2      108      1
# 2     67    1      asymptomatic       120   229    0        2      129      1
# 3     37    1  non-anginal pain       130   250    0        0      187      0
# 4     41    0   atypical angina       130   204    0        2      172      0
# ..   ...  ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    1    typical angina       110   264    0        0      132      0
# 299   68    1      asymptomatic       144   193    1        0      141      0
# 300   57    1      asymptomatic       130   131    0        0      115      1
# 301   57    0   atypical angina       130   236    0        2      174      0
# 302   38    1  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak        slope      ca               thal  num
# 0        2.3  downsloping       0       fixed defect    0
# 1        1.5         flat       3             normal    1
# 2        2.6         flat       2  reversable defect    1
# 3        3.5  downsloping       0             normal    0
# 4        1.4    upsloping       0             normal    0
# ..       ...          ...     ...                ...  ...
# 298      1.2         flat       0  reversable defect    1
# 299      3.4         flat       2  reversable defect    1
# 300      1.2         flat       1  reversable defect    1
# 301      0.0         flat       1             normal    1
# 302      0.0    upsloping -100000             normal    0
#
# [303 rows x 14 columns]

# %% [markdown]
# #### Removing the outliers from the coumns

# %%
data['thal'].unique()
# Out:
# array(['fixed defect', 'normal', 'reversable defect', None], dtype=object)

# %%
#Replacing the outliers (None with mode)

data['thal'].mode()[0]
# Out:
# 'normal'

# %%
data['thal'] = data['thal'].fillna('normal')

# %%
data['thal'].unique()
# Out:
# array(['fixed defect', 'normal', 'reversable defect'], dtype=object)

# %%
data['ca'].unique()
# Out:
# array([      0,       3,       2,       1, -100000], dtype=int64)

# %%
data['ca'] = data['ca'].replace(-100000, 0)

# %%
data['ca'].unique()
# Out:
# array([0, 3, 2, 1], dtype=int64)

# %% [markdown]
# ### Now Our data is clear & simple so we can continue with E.D.A

# %%
Person_having_Heart_Disease = data.age.where(data.num == 1)

sns.histplot(Person_having_Heart_Disease)
plt.title('No. of people having Heart disease');

# %% [markdown]
# #### Above plot shows that count of people having Heart Disease at different age, and people with age between 60-65 has highest count.

# %%
Healthy_Person = data.age.where(data.num == 0)

sns.histplot(Healthy_Person)
plt.title('No. of people having No Heart disease');

# %% [markdown]
# ##### Above plot shows that count of people having No Heart Disease at different age, and people with age between 50-55 has highest count.

# %%
def heart_disease(row):
    if row == 0:
        return 'Absence'
    elif row==1:
        return 'Presence'

# %%
data.groupby('num').size()
# Out:
# num
# 0    164
# 1    139
# dtype: int64

# %%
data['Heart_Disease'] = data['num'].apply(heart_disease)

# %% [markdown]
# ##### Here we have created a column named Heart_Disease for a better Visulisation

# %%
data.head()
# Out:
#    age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63    1    typical angina       145   233    1        2      150      0
# 1   67    1      asymptomatic       160   286    0        2      108      1
# 2   67    1      asymptomatic       120   229    0        2      129      1
# 3   37    1  non-anginal pain       130   250    0        0      187      0
# 4   41    0   atypical angina       130   204    0        2      172      0
#
#    oldpeak        slope  ca               thal  num Heart_Disease
# 0      2.3  downsloping   0       fixed defect    0       Absence
# 1      1.5         flat   3             normal    1      Presence
# 2      2.6         flat   2  reversable defect    1      Presence
# 3      3.5  downsloping   0             normal    0       Absence
# 4      1.4    upsloping   0             normal    0       Absence

# %%
data.hist(figsize = (14,12))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'sex'}>,
#         <AxesSubplot:title={'center':'trestbps'}>],
#        [<AxesSubplot:title={'center':'chol'}>,
#         <AxesSubplot:title={'center':'fbs'}>,
#         <AxesSubplot:title={'center':'restecg'}>],
#        [<AxesSubplot:title={'center':'thalach'}>,
#         <AxesSubplot:title={'center':'exang'}>,
#         <AxesSubplot:title={'center':'oldpeak'}>],
#        [<AxesSubplot:title={'center':'ca'}>,
#         <AxesSubplot:title={'center':'num'}>, <AxesSubplot:>]],
#       dtype=object)

# %%
data.shape
# Out:
# (303, 15)

# %%
##Dropping the num column as we have Heart_Disease column

data.drop('num',axis=1,inplace=True)

# %%
data
# Out:
#      age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1    typical angina       145   233    1        2      150      0
# 1     67    1      asymptomatic       160   286    0        2      108      1
# 2     67    1      asymptomatic       120   229    0        2      129      1
# 3     37    1  non-anginal pain       130   250    0        0      187      0
# 4     41    0   atypical angina       130   204    0        2      172      0
# ..   ...  ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    1    typical angina       110   264    0        0      132      0
# 299   68    1      asymptomatic       144   193    1        0      141      0
# 300   57    1      asymptomatic       130   131    0        0      115      1
# 301   57    0   atypical angina       130   236    0        2      174      0
# 302   38    1  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak        slope  ca               thal Heart_Disease
# 0        2.3  downsloping   0       fixed defect       Absence
# 1        1.5         flat   3             normal      Presence
# 2        2.6         flat   2  reversable defect      Presence
# 3        3.5  downsloping   0             normal       Absence
# 4        1.4    upsloping   0             normal       Absence
# ..       ...          ...  ..                ...           ...
# 298      1.2         flat   0  reversable defect      Presence
# 299      3.4         flat   2  reversable defect      Presence
# 300      1.2         flat   1  reversable defect      Presence
# 301      0.0         flat   1             normal      Presence
# 302      0.0    upsloping   0             normal       Absence
#
# [303 rows x 14 columns]

# %% [markdown]
# ## Calculating How Many People Have Heart Disease, And How Many Don't Have Heart Disease In This Dataset

# %%
sns.countplot(data['Heart_Disease'])
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Heart_Disease', ylabel='count'>

# %%
hd = data.groupby('Heart_Disease').size()

# %%
hd
# Out:
# Heart_Disease
# Absence     164
# Presence    139
# dtype: int64

# %%
plt.figure(figsize=(10,7))
plt.pie(hd,labels=['Absence','Presence'],autopct='%0.0f%%')
plt.title("Heart Disease Population %age",fontsize=20)
plt.show()

# %% [markdown]
# ### From the overall population, people having heart disease are 46% and those who doesn't have heart disease are 56%

# %% [markdown]
# ## Finding the Count of Male & Female in this Dataset

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     97
# Name: sex, dtype: int64

# %%
sns.countplot(data['sex'])
plt.xticks([0,1],['Female', 'Male'])
plt.show()
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ## Finding the Gender distribution accoding to the Heart_Disease

# %%
sns.countplot(x='sex',hue="Heart_Disease",data=data)
plt.xticks([1,0],['Male','Female'])
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ## Check Chest Pain Type

# %% [markdown]
# Value 1: typical angina
#
# Value 2: atypical angina
#
# Value 3: non-anginal pain
#
# Value 4: asymptomatic

# %%
sns.countplot(data['cp'])
plt.xticks([0,1,2,3],["typical angina","atypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=75)
plt.show()
# Out:
# C:\Users\Aishwarya\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# ### Showing The Chest Pain Distribution As Per the Heart_Disease

# %%
sns.countplot(x="cp", hue="Heart_Disease", data=data)
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ### Show Fasting Blood Sugar Level Distribution According To Heart_Disease

# %%
sns.countplot(x="fbs", hue="Heart_Disease", data=data)
plt.legend(labels = ['No-Disease','Disease'])
plt.show()

# %% [markdown]
# ### Checking Resting Blood Pressure Distribution

# %%
data['trestbps'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Checking cholesterol measurement Distribution

# %%
data['chol'].hist()
# Out:
# <AxesSubplot:>

# %% [markdown]
# #### Basic stats of the dataset

# %%
Min_age = data['age'].min()
Max_age = data['age'].max()
Mean_age = data['age'].mean()
print("Minimum age is: {0}\nMaximum age is: {1}\nMean of Age is: {2}".format(Min_age,Max_age,Mean_age))
# Out:
# Minimum age is: 29
# Maximum age is: 77
# Mean of Age is: 54.43894389438944

# %% [markdown]
# ##### Converting the age column into three subclass

# %%
Young_age = data[(data['age']>=29) & (data['age']<40)]
Mid_age = data[(data['age']>=40) & (data['age'] <55)]
Old_age = data[(data['age']>=55)]

# %%
print("Number of Young age people are: {0}\nNumber of Middly age people are: {1}\nNumber of Elder age People are: {2}".format(len(Young_age),len(Mid_age),len(Old_age)))
# Out:
# Number of Young age people are: 15
# Number of Middly age people are: 128
# Number of Elder age People are: 160

# %% [markdown]
# ### Showing the count of  age distribution According To Heart_Disease

# %%
sns.barplot(x=['Young_age','Mid_age','Old_age'],y=[len(Young_age),len(Mid_age),len(Old_age)])
plt.title('Age Category',fontsize=17)
plt.xlabel(xlabel='Age Range',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=17)
plt.show()

# %%
#Converting Numerical Data into Categorical Data
# Male = 1 and female = 0

def Sex(row):
    if (row==1):
        return 'Male'
    elif (row==0):
        return 'Female'

# %%
data['Sex']=data['sex'].apply(Sex)

# %%
data
# Out:
#      age  sex                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    1    typical angina       145   233    1        2      150      0
# 1     67    1      asymptomatic       160   286    0        2      108      1
# 2     67    1      asymptomatic       120   229    0        2      129      1
# 3     37    1  non-anginal pain       130   250    0        0      187      0
# 4     41    0   atypical angina       130   204    0        2      172      0
# ..   ...  ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    1    typical angina       110   264    0        0      132      0
# 299   68    1      asymptomatic       144   193    1        0      141      0
# 300   57    1      asymptomatic       130   131    0        0      115      1
# 301   57    0   atypical angina       130   236    0        2      174      0
# 302   38    1  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak        slope  ca               thal Heart_Disease     Sex
# 0        2.3  downsloping   0       fixed defect       Absence    Male
# 1        1.5         flat   3             normal      Presence    Male
# 2        2.6         flat   2  reversable defect      Presence    Male
# 3        3.5  downsloping   0             normal       Absence    Male
# 4        1.4    upsloping   0             normal       Absence  Female
# ..       ...          ...  ..                ...           ...     ...
# 298      1.2         flat   0  reversable defect      Presence    Male
# 299      3.4         flat   2  reversable defect      Presence    Male
# 300      1.2         flat   1  reversable defect      Presence    Male
# 301      0.0         flat   1             normal      Presence  Female
# 302      0.0    upsloping   0             normal       Absence    Male
#
# [303 rows x 15 columns]

# %%
#Dropping the sex column
data.drop('sex',axis=1,inplace=True)

# %%
data.head()
# Out:
#    age                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63    typical angina       145   233    1        2      150      0
# 1   67      asymptomatic       160   286    0        2      108      1
# 2   67      asymptomatic       120   229    0        2      129      1
# 3   37  non-anginal pain       130   250    0        0      187      0
# 4   41   atypical angina       130   204    0        2      172      0
#
#    oldpeak        slope  ca               thal Heart_Disease     Sex
# 0      2.3  downsloping   0       fixed defect       Absence    Male
# 1      1.5         flat   3             normal      Presence    Male
# 2      2.6         flat   2  reversable defect      Presence    Male
# 3      3.5  downsloping   0             normal       Absence    Male
# 4      1.4    upsloping   0             normal       Absence  Female

# %%
def Age_range(row):
    if (row>=29 and row <40):
        return 'Young age'
    elif(row >=40 and row <55):
        return 'Mid age'
    elif (row >= 55 and row <78):
        return 'Old age'

# %%
data['Age_range']=data['age'].apply(Age_range)

# %%
data.head()
# Out:
#    age                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0   63    typical angina       145   233    1        2      150      0
# 1   67      asymptomatic       160   286    0        2      108      1
# 2   67      asymptomatic       120   229    0        2      129      1
# 3   37  non-anginal pain       130   250    0        0      187      0
# 4   41   atypical angina       130   204    0        2      172      0
#
#    oldpeak        slope  ca               thal Heart_Disease     Sex  \
# 0      2.3  downsloping   0       fixed defect       Absence    Male
# 1      1.5         flat   3             normal      Presence    Male
# 2      2.6         flat   2  reversable defect      Presence    Male
# 3      3.5  downsloping   0             normal       Absence    Male
# 4      1.4    upsloping   0             normal       Absence  Female
#
#    Age_range
# 0    Old age
# 1    Old age
# 2    Old age
# 3  Young age
# 4    Mid age

# %% [markdown]
# ### Checking the Heart Disease based on age range

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Heart_Disease',hue='Age_range',data=data,order=['Presence','Absence'],hue_order=['Young age','Mid age','Old age'],palette='Pastel1')
plt.title("Heart Disease based on Age Range",fontsize=20)
plt.xlabel(xlabel='Heart Disease',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.show()

# %% [markdown]
# ### Old people are more affected by Heart Disease compared to other ages and middle aged people are more free from Heart Disease compared to other ages

# %% [markdown]
# ## Chest pain based on gender

# %%
plt.figure(figsize=(15,7))
sns.countplot(x='Sex',hue='cp',data=data)
plt.title("Chest pain based on Gender",fontsize=15)
plt.xlabel(xlabel='Gender',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %% [markdown]
# #### We can see that a higher number of men are suffering from Asymptomatic type of Chest Pain

# %% [markdown]
# ### Checking the Chest pain based on Gender Category

# %%
plt.figure(figsize=(15,7),frameon=True)
sns.countplot(x='Age_range',hue='cp',data=data,order=['Young age','Mid age','Old age'])
plt.xlabel(xlabel='Age Category',fontsize=15)
plt.ylabel(ylabel='Count',fontsize=15)
plt.title("Chest pain based on Gender Category")
plt.legend(labels=['Typical Angina','Atypical Angina','Non-Anginal pain','Asymptomatic'])
plt.show()

# %%
plt.figure()
sns.barplot(x='Heart_Disease',y='chol',data=data)
plt.xlabel(xlabel='Heart Disease',fontsize=15)
plt.ylabel(ylabel='Cholesterol level(mg/dl)',fontsize=15)
plt.title("Heart Disease v/s Cholesterol Level")
plt.show()

# %% [markdown]
# #### More Cholesterol means More chance of Heart Disease

# %% [markdown]
# ### Checking maximum Heart rate achived

# %%
fig = sns.histplot(data['thalach'], bins= 20)
fig.set(xlabel = 'maximum heart rate achieved')
# Out:
# [Text(0.5, 0, 'maximum heart rate achieved')]

# %% [markdown]
# #### The maximum heart rate achieved seems to be between 150 - 170.

# %%
sns.barplot(x='Sex', y='oldpeak', data=data, palette='twilight_r')
plt.title('ST depression VS Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('ST depression', fontsize=15)
plt.show()

# %% [markdown]
# #### Males are more prone to ST dipression

# %%
sns.barplot(x='Sex', y='exang', data=data, palette='binary_r')
plt.title('Exercise With Angina VS Gender', fontsize=17)
plt.xlabel('Gender', fontsize=15)
plt.ylabel('Exercise With Angina', fontsize=15)
plt.show()

# %% [markdown]
# #### Males have have high Exercise Angina
#
# #### Angina is a type of chest pain caused by reduced blood flow to the heart.

# %% [markdown]
# ## Correlations

# %% [markdown]
# ###### Now that we analyzed all the factors, let's see what the corrolation heatmap gives us:

# %%
corr = data.corr()
plt.subplots(figsize=(11, 9))
cmap = sns.diverging_palette(250, 30, as_cmap=True)
sns.heatmap(corr, cmap=cmap, center=0, square=True, linewidths=.5)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(16,9))
sns.heatmap(data.corr(), annot=True, linewidth=3)
# Out:
# <AxesSubplot:>

# %% [markdown]
# ##### Checking the dataset to check un-wanted values

# %%
data
# Out:
#      age                cp  trestbps  chol  fbs  restecg  thalach  exang  \
# 0     63    typical angina       145   233    1        2      150      0
# 1     67      asymptomatic       160   286    0        2      108      1
# 2     67      asymptomatic       120   229    0        2      129      1
# 3     37  non-anginal pain       130   250    0        0      187      0
# 4     41   atypical angina       130   204    0        2      172      0
# ..   ...               ...       ...   ...  ...      ...      ...    ...
# 298   45    typical angina       110   264    0        0      132      0
# 299   68      asymptomatic       144   193    1        0      141      0
# 300   57      asymptomatic       130   131    0        0      115      1
# 301   57   atypical angina       130   236    0        2      174      0
# 302   38  non-anginal pain       138   175    0        0      173      0
#
#      oldpeak        slope  ca               thal Heart_Disease     Sex  \
# 0        2.3  downsloping   0       fixed defect       Absence    Male
# 1        1.5         flat   3             normal      Presence    Male
# 2        2.6         flat   2  reversable defect      Presence    Male
# 3        3.5  downsloping   0             normal       Absence    Male
# 4        1.4    upsloping   0             normal       Absence  Female
# ..       ...          ...  ..                ...           ...     ...
# 298      1.2         flat   0  reversable defect      Presence    Male
# 299      3.4         flat   2  reversable defect      Presence    Male
# 300      1.2         flat   1  reversable defect      Presence    Male
# 301      0.0         flat   1             normal      Presence  Female
# 302      0.0    upsloping   0             normal       Absence    Male
#
#      Age_range
# 0      Old age
# 1      Old age
# 2      Old age
# 3    Young age
# 4      Mid age
# ..         ...
# 298    Mid age
# 299    Old age
# 300    Old age
# 301    Old age
# 302  Young age
#
# [303 rows x 15 columns]

# %%
data.to_csv('Heart Disease Final dataset.csv', index=False)

# %% [markdown]
# ## Conclusions:
# 1) From target value we can say that our dataset is amost balanced with 54% of patients having no heart disease and 46 % of patients having heart disease.
#
# 2) Males have higher chances of having heart disease than females.
#
# 3) Patients with age >55 years and having resting blood suger( i.e in diastolic state) in range 121-140 mm Hg have higher chances of heart disease. patients with age group 40 to 45 have little chances and age below 40 has negligiable cgances of having a heart disease.
#
# 4) Patients suffering from heart disease are mostly in age group of 55-65 years.
#
# 5) Higher cholesterol means higher chances of heart disease. it plays an important role in determining heart problems. With age cholesterol increases and level 200- 350 mg/dl are of concern.
#
# 6) Patients showing definite left ventricular hypertrophy in Resting electrocardiographic measurement are more likely to suffer from a heart disease.
#
# 7) Patients who are likely to suffer from heart disease have higher maximum heart rates( rate between 140-160) whereas patients who are not likely to suffer from heart disease are having lower maximum heart rates.
#
# 8) Exercise induced anginal pain slightly higher chances of getting heart disease than without exercise induced pain.
#
# 9) Patients having no thalassaemia can also suffer from heart disease, but patients having reversable effect thalassaemia have greater chances of suffering from heart disease. So thalassaemia plays an important role in detecting heart disease.
#
# 10) St_depression >0.5 mm in ECG indicates abnormality. Therefore the slope of the peak exercise ST segment showing downslope with st_depression>0.5 mm has greater chances of heart disease.
